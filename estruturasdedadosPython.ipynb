# %%
#Criando uma lista chamada animais
animais = [1,2,3]
animais
# Out:
# [1, 2, 3]

# %%
animais = ["cachorro","gato", 12345,6.5]
animais
# Out:
# ['cachorro', 'gato', 12345, 6.5]

# %%
animais[0]
# Out:
# 'cachorro'

# %%
animais[3]
# Out:
# 6.5

# %%
animais[0] = "papagaios"
animais
# Out:
# ['papagaios', 'gato', 12345, 6.5]

# %%
animais.remove("gato")

# %%
animais
# Out:
# ['papagaios', 12345, 6.5]

# %%
len(animais)
# Out:
# 3

# %%
"gato" in animais
# Out:
# False

# %%
lista = [500,30,300,80,10]

# %%
max(lista)
# Out:
# 500

# %%
min(lista)
# Out:
# 10

# %%
animais.append("leão")

# %%
animais
# Out:
# ['papagaios', 12345, 6.5, 'leão']

# %%
animais.extend(["cobra",6])

# %%
animais
# Out:
# ['papagaios', 12345, 6.5, 'leão', 'cobra', 6]

# %%
animais.count("cachorro")
# Out:
# 0

# %%
lista.sort()

# %%
lista
# Out:
# [10, 30, 80, 300, 500]

# %%
#tuplas usam parenteses como sistaxe
tp = ("Banana","Maça",10,50)

# %%
tp[0]
# Out:
# 'Banana'

# %%
#tuplas não permitem alterações
tp[0] = "laranja"

# %%
tp.count("Maça")
# Out:
# 1

# %%
tp[0:2]
# Out:
# ('Banana', 'Maça')

# %%
#dicionario para criar utiliza a chave
dc = {"Maça":20,"Banana":10,"Laranja":15,"Uva":5} #dicionarios trabalha com chave e valor

# %%
dc
# Out:
# {'Maça': 20, 'Banana': 10, 'Laranja': 15, 'Uva': 5}

# %%
dc["Maça"] #acessando o valor de um dicionario atraves da chave
# Out:
# 20

# %%
dc["Maça"] = 25 #atualizando o valor de maça
dc
# Out:
# {'Maça': 25, 'Banana': 10, 'Laranja': 15, 'Uva': 5}

# %%
dc.keys() #retornando todas as chaves do dicionario
# Out:
# dict_keys(['Maça', 'Banana', 'Laranja', 'Uva'])

# %%
dc.values() #retornando todas os valores do dicionario
# Out:
# dict_values([25, 10, 15, 5])

# %%
dc.setdefault("Limão",22) #verificando se ja existe uma chave no dicionario e cas nao exita inserir
# Out:
# 22

# %%
dc
# Out:
# {'Maça': 25, 'Banana': 10, 'Laranja': 15, 'Uva': 5, 'Limão': 22}
